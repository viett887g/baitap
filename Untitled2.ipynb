# %% [markdown]
# <a href="https://colab.research.google.com/github/viett887g/baitap/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('python')
# Out:
# python

# %%
number=(1,2,3,4,5)
number_sum= sum(number)
print(number_sum)
# Out:
# 15

# %%
number=(1,2,3,4,5)
number_prog= math.prog(number)
print(number_prog)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-459b89e863db> in <module>()
#       1 number=(1,2,3,4,5)
# ----> 2 number_prog=math.prog(number)
#       3 print(number_prog)
#
# NameError: name 'math' is not defined

# %%
number=(1,2,3,4,5)
numbermax= max(number)
print(numbermax)
# Out:
# 5

# %%
number=(1,2,3,4,5)
numbermin= min(number)
print(numbermin)
# Out:
# 1

# %%
number=(1,2,3,4,5)
numbersort= sort(number)
print(numbersort)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-72d558fb750b> in <module>()
#       1 number=(1,2,3,4,5)
# ----> 2 numbersort= sort(number)
#       3 print(numbersort)
#
# NameError: name 'sort' is not defined
